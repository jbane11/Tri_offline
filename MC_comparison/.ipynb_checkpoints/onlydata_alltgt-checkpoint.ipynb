# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import pandas as pd
import matplotlib.pyplot as plt
import os,sys
import glob
import numpy as np



tgt="D2"

Xaxis="Xbj" #theta / Xbj
if Xaxis == "Xbj":
    xaxis="xbj"
else :
    xaxis="theta"

    
#runs=[1207,1233,1279,2570,1344,2632]
#if len(sys.argv) >1:
#    for i in range(1,len(sys.argv),1):
#        runs.append(sys.argv[i])
#else :
#    print('Please enter the runs you want to look at! -1 when done')
#    run=0
#    i=0
#    while run is not -1:
#        i=i+1
#        run=int(input("{}  ".format(i)))
#        if run==-1:
#            break
#        runs.append(run)       
#print( "Will look at runs ", runs)
mcfile='/home/jbane/tritium/Tri_offline/MC_comparison/yield_output/{}/'.format(xaxis)
datafile='/home/jbane/tritium/Tri_offline/yield/yield_output/{}/'.format(xaxis)
kins={}
kin={}

kins=sorted(glob.glob('{}{}*.dat'.format(datafile,tgt)))

mcDF={}
dataDF={}
mcDFs={}
dataDFs={}
ratios={}
i=0
for i in range(len(kins)):
    kin[i] = kins[i].replace(datafile,"")
    kin[i] = kin[i].replace('.dat',"")
    
    #print(kin[i])
    mcfileR=mcfile+'{}.dat'.format(kin[i])
    datafileR=datafile+'{}.dat'.format(kin[i])
    #print(datafileR)
    chk1=0
    chk=0
    if os.path.isfile(mcfileR):
        chk=1
    else:
        print("MC file does not exist") 
        chk=0
    if os.path.isfile(datafileR):
        chk1=1
    else :
        print("Data file does not exist")
        chk1=0
    #f chk==0 or chk1==0:
    #    continue     

    #mcDF[i]=pd.read_table(mcfileR,delim_whitespace=True)
    dataDF[i]=pd.read_table(datafileR,delim_whitespace=True)
    
 
    #mcDF[i]['yield']=mcDF[i]['Yield']/1000.0
    #mcDF[i]['Error']=mcDF[i]['Error']/1000.0
    
    dataDF[i]['yield']=dataDF[i]['Yield']
    #mcmed=mcDF[i]['yield'].mean()
    datamed=dataDF[i]['yield'].mean()
    #mcDFs[i]=mcDF[i][mcDF[i]['yield'] >=mcmed *0.5]
    dataDFs[i]=dataDF[i][dataDF[i]['yield'] >= datamed *0.5].copy()
    #mcDFs[i]=mcDFs[i].dropna()
    dataDFs[i]=dataDFs[i].dropna()
    #drop the first 2 and last 2 bins
    
    #dataDFs[i]=dataDFs[i].drop(dataDFs[i].index[0])
    #dataDFs[i]=dataDFs[i].drop(dataDFs[i].index[0])
    dl=len(dataDFs[i])
    #dataDFs[i]=dataDFs[i].drop(dataDFs[i].index[dl-1])
    #dataDFs[i]=dataDFs[i].drop(dataDFs[i].index[dl-2])    
    
  #  mcDFs[i]=mcDFs[i].drop(mcDFs[i].index[0])
  #  mcDFs[i]=mcDFs[i].drop(mcDFs[i].index[0])
    ml=len(dataDFs[i])
  #  mcDFs[i]=mcDFs[i].drop(mcDFs[i].index[ml-1])
  #  mcDFs[i]=mcDFs[i].drop(mcDFs[i].index[ml-2])
    
    
   
    if len(dataDFs[i]) <2 :
            continue
    print(len(dataDFs[i].index), len(dataDFs[i]))       
                #cut put the edge bins for now
        
        
    if len(dataDFs[i]) >=5 :   
        #dataDFs[i]=dataDFs[i].drop(dataDFs[i].index[0])
        #dataDFs[i]=dataDFs[i].drop(dataDFs[i].index[0])
        last= len(dataDFs[i].index)
        #dataDFs[i]=dataDFs[i].drop(dataDFs[i].index[last-1])
        #dataDFs[i]=dataDFs[i].drop(dataDFs[i].index[last-2])
    print(len(dataDFs[i].index), len(dataDFs[i]))
    #minind= dataDFs[i].index[0]
    #axind=dataDFs[i].index[len(dataDFs[i].index)-1]
    
    #mcDFs[i]=mcDFs[i][mcDFs[i].index>=minind]
    #mcDFs[i]=mcDFs[i][mcDFs[i].index<=maxind]        
    dataDFs[i] =dataDFs[i][dataDFs[i].index  >= dataDFs[i]["Ne"].idxmax()]     
    
    print(i,kin[i])
    print(dataDFs[i])
    #dataDFs[i]= dataDFs[i].drop(dataDFs[i].index[[0,len(dataDFs[i])-1]])
    #mcDFs[i]=     mcDFs[i].drop(mcDFs[i].index[  [0,  len(mcDFs[i])-1]])
    dataDFs[i]['Stat_err']=1.0/np.sqrt((dataDFs[i]['Ne']))*dataDFs[i]['yield']*10
    #ratios[i] = mcDFs[i].copy()
    #ratios[i].drop('yield')
    #ratios[i]['data_Y'] =dataDFs[i]['yield']
    #ratios[i]['MC_Y'] = mcDFs[i]['yield']
    #ratios[i]['ratio'] = dataDFs[i]['yield']/mcDFs[i]['yield']
    #ratios[i]['offset'] = dataDFs[i]['yield'] - mcDFs[i]['yield']
 
    #i=i+1
    
import matplotlib._color_data as mcd
overlap = [name for name in mcd.CSS4_COLORS if "xkcd:" + name in mcd.XKCD_COLORS]

markers =[[3,0,0]  ,[5,1,90] ,[4,0,90],[3,1,90],[6,2,0] ,[5,0,0] ,[4,1,0],[3,0,0]]
markers2 =[[3,0,0] ,[5,1,90] ,[4,0,90],[3,1,90],[6,2,0] ,[5,0,70],[4,1,0],[3,0,0]]
colors=['red', 'Green', 'Blue', 'Orange', 'Purple', 'Cyan', 'Magenta','Teal','Brown','Maroon','Navy']#, f032e6, bcf60c, fabebe, 008080, e6beff, 9A6324, fffac8, 800000, aaffc3, 808000, ffd8b1, 000075, a9a9a9, ffffff, 000000]
fig= plt.figure(dpi=200,figsize=(9,5))
ax=fig.add_subplot(1,1,1)
#plt.title('{} Data to MC comparison'.format(tgt))
#bx=fig.add_subplot(2,1,2, sharex=ax)
#fig2=plt.figure(dpi=200,figsize=(9,5))
#bx=fig2.add_subplot(1,1,1)
plt.title('{} Luminosity Normalized yields'.format(tgt))
#fig,bx=plt.subplots(dpi=250)
k=int(0)
m=int(0)
j=int(0)
for DF in dataDFs:
    xkcd = mcd.XKCD_COLORS["xkcd:" + overlap[j]].upper()
    xkcd2 = mcd.XKCD_COLORS["xkcd:" + overlap[j+len(mcDF)]].upper()
    print(j , kin[j])
    #print()
    if k == 7:
        k = 0
    if m == 8:
        m = 0
    #if(len(dataDFs[j])) == 0:
     #   continue

    #if j == 110:
     #   ax = mcDFs[j].plot(x='theta',y='yield',yerr=':error',kind='scatter', marker=markers[j], color='blue', label='MC run{}'.format(runs[j]))
    #else :
    #mcDFs[j].plot(ax=ax,x='{}'.format(Xaxis),y='yield',yerr='Error',kind='scatter',marker=markers[j], color='blue', label='MC {}'.format(kin[j]))
    if kin[DF]=="He3_kin16":
        continue
    dataDFs[DF].plot(ax=ax,x='{}'.format(Xaxis),y='yield',yerr='Error',kind='scatter', marker=markers2[m], color=colors[j], label='data {}'.format(kin[DF]))
    #dataDFs[j].plot(ax=ax,x='{}'.format(Xaxis),y='yield',yerr='Stat_err',kind='scatter', marker=markers2[m], color=colors[j], label='data {}'.format(kin[j]))
    #dataDFs[j].plot(ax=bx,x='{}'.format(Xaxis),y='yield',yerr='Stat_err',kind='scatter', marker=markers2[m], color='r')
    #ratios[j].plot(ax=bx,x='{}'.format(Xaxis) ,y='ratio', xerr='offset', kind='scatter', label='{}'.format(kin[j]),marker=markers2[j] )
    print(j , kin[j])
    k=k+1
    m=m+1
    j=j+1
       
ax.set_yscale("log")
ax.grid(True)
#bx.grid(True)
ax.legend(ncol=2)
#bx.legend(ncol=2)
bx.set_yscale("log")
bx.grid(True)
fig.subplots_adjust(hspace=0)
fig.savefig('images/{}_dataall.png'.format(tgt))

fig2.savefig('images/{}_onecolor.png'.format(tgt))
# Out:
# <style>.container { width:100% !important; }</style>
# 2 2
# 2 2
# 0 D2_kin1
#          Xbj  Ne         Yield         Error         yield
# 9   0.298947   1 -9.486140e-07 -9.486470e-07 -9.486140e-07
# 24  0.539848   1 -7.757250e-06 -7.757530e-06 -7.757250e-06
# MC file does not exist
# 2 2
# 2 2
# 1 D2_kin11
#          Xbj  Ne     Yield     Error     yield
# 23  0.531998  59 -0.000038 -0.000005 -0.000038
# 35  0.712114   1 -0.000003 -0.000003 -0.000003
# MC file does not exist
# 2 2
# 2 2
# 2 D2_kin13
#          Xbj   Ne     Yield     Error     yield
# 28  0.609825  245 -0.000145 -0.000009 -0.000145
# 40  0.795024    5 -0.000014 -0.000006 -0.000014
# MC file does not exist
# 2 2
# 2 2
# 3 D2_kin15
#          Xbj  Ne     Yield     Error     yield
# 32  0.676758  21 -0.000008 -0.000002 -0.000008
# 45  0.874465  15 -0.000030 -0.000008 -0.000030
# MC file does not exist
# 10 10
# 10 10
# 4 D2_kin16
#          Xbj   Ne    Yield     Error    yield
# 34  0.703969  279 -0.00010 -0.000006 -0.00010
# 46  0.886416   18 -0.00003 -0.000007 -0.00003
# 3 3
# 3 3
# 6 D2_kin3
#          Xbj   Ne     Yield     Error     yield
# 5   0.244421  664 -0.000125 -0.000005 -0.000125
# 13  0.359298   35 -0.000019 -0.000003 -0.000019
# 2 2
# 2 2
# 7 D2_kin4
#          Xbj  Ne         Yield         Error         yield
# 7   0.276788  16 -4.281350e-06 -1.070640e-06 -4.281350e-06
# 16  0.412934   1 -9.007370e-07 -9.007530e-07 -9.007370e-07
# MC file does not exist
# MC file does not exist
# 2 2
# 2 2
# 9 D2_kin7
#          Xbj   Ne     Yield     Error     yield
# 14  0.387711  103 -0.000077 -0.000008 -0.000077
# 24  0.534815    2 -0.000005 -0.000004 -0.000005
# MC file does not exist
# 0 D2_kin1
# 0 D2_kin1
# 1 D2_kin11
# 1 D2_kin11
# 2 D2_kin13
# 2 D2_kin13
# 3 D2_kin15
# 3 D2_kin15
# 4 D2_kin16
# 4 D2_kin16
# 5 D2_kin2
# 5 D2_kin2
# 6 D2_kin3
# 6 D2_kin3
# 7 D2_kin4
# 7 D2_kin4
# 8 D2_kin5
# 8 D2_kin5
# 9 D2_kin7
# 9 D2_kin7
# 10 D2_kin9
# 10 D2_kin9

# %%
dataDFs[8]
# Out:
#       theta    Ne     Yield     Error     yield  Stat_err
# 30  21.9277  2973  0.000171  0.211396  0.000171  0.000031
# 31  22.1485  3120  0.000179  0.206255  0.000179  0.000032
# 32  22.3747  2909  0.000166  0.212262  0.000166  0.000031
# 33  22.6011  2720  0.000156  0.221276  0.000156  0.000030
# 34  22.8279  2496  0.000143  0.231080  0.000143  0.000029
# 35  23.0569  2325  0.000133  0.238556  0.000133  0.000028
# 36  23.2835  2189  0.000125  0.245177  0.000125  0.000027
# 37  23.5126  2036  0.000117  0.255714  0.000117  0.000026
# 38  23.7393  1805  0.000103  0.270014  0.000103  0.000024
# 39  23.9673  1830  0.000105  0.270008  0.000105  0.000025
# 40  24.1930  1651  0.000095  0.282138  0.000095  0.000023
# 41  24.4188  1448  0.000083  0.300018  0.000083  0.000022
